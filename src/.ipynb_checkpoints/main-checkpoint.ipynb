# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 数据概况的观察
#     - 使用pd.read_csv()完成数据的提取
#     - 使用DataFrame.describe()完成数据概况的观察
# ## 数据列的提取
#     - 把pd.read_csv()提取出来的DataFrame对象保存起来

# %%
path1 = "./data/customer.csv"
path2 = "./data/holiday_mst.csv"
path3 = "./data/hotel.csv"
path4 = "./data/reserve.csv"

customer = pd.read_csv(path1)
holiday_mst = pd.read_csv(path2)
hotel = pd.read_csv(path3)
reserve = pd.read_csv(path4)

print('表customer:')
print(customer)
print(customer.describe())
print('\n\n\n')

print('表holiday_mst:')
print(holiday_mst)
print(holiday_mst.describe())
print('\n\n\n')

print('表hotel:')
print(hotel)
print(hotel.describe())
print('\n\n\n')

print('表reserve:')
print(reserve)
print(reserve.describe())
print('\n\n\n')
# Out:
# 表customer:
#     customer_id  age    sex  home_latitude  home_longitude
# 0           c_1   41    man      35.092193      136.512347
# 1           c_2   38    man      35.325076      139.410551
# 2           c_3   49  woman      35.120543      136.511179
# 3           c_4   43    man      43.034868      141.240314
# 4           c_5   31    man      35.102661      136.523797
# ..          ...  ...    ...            ...             ...
# 995       c_996   44    man      34.465648      135.373787
# 996       c_997   35    man      35.345372      139.413754
# 997       c_998   32  woman      43.062267      141.272126
# 998       c_999   48  woman      38.172800      140.464198
# 999      c_1000   39    man      35.452412      139.411310
#
# [1000 rows x 5 columns]
#               age  home_latitude  home_longitude
# count  1000.00000    1000.000000     1000.000000
# mean     51.27500      36.301492      137.101549
# std      14.76548       3.024908        3.590634
# min      21.00000      33.264641      130.290768
# 25%      39.00000      34.444472      135.373918
# 50%      49.00000      35.294221      139.390638
# 75%      63.00000      38.172066      140.450375
# max      89.00000      43.063960      141.274039
#
#
#
#
# 表holiday_mst:
#       target_day  holidayday_flg  nextday_is_holiday_flg
# 0     2016-01-01            True                    True
# 1     2016-01-02            True                    True
# 2     2016-01-03            True                   False
# 3     2016-01-04           False                   False
# 4     2016-01-05           False                   False
# ...          ...             ...                     ...
# 1181  2019-03-27           False                   False
# 1182  2019-03-28           False                   False
# 1183  2019-03-29           False                    True
# 1184  2019-03-30            True                    True
# 1185  2019-03-31            True                   False
#
# [1186 rows x 3 columns]
#         target_day holidayday_flg nextday_is_holiday_flg
# count         1186           1186                   1186
# unique        1186              2                      2
# top     2018-02-05          False                  False
# freq             1            794                    795
#
#
#
#
# 表hotel:
#     hotel_id  base_price big_area_name small_area_name  hotel_latitude  \
# 0        h_1       26100             D             D-2       43.064569
# 1        h_2       26400             A             A-1       35.715320
# 2        h_3       41300             E             E-4       35.281572
# 3        h_4        5200             C             C-3       38.431293
# 4        h_5       13500             G             G-3       33.597291
# ..       ...         ...           ...             ...             ...
# 295    h_296       17200             F             F-4       34.638426
# 296    h_297       30000             A             A-3       35.815512
# 297    h_298        9800             A             A-1       35.717254
# 298    h_299       24200             C             C-2       38.335725
# 299    h_300       16300             C             C-1       38.232803
#
#      hotel_longitude  is_business
# 0         141.511397         True
# 1         139.939446         True
# 2         136.988565        False
# 3         140.795615        False
# 4         130.533872         True
# ..               ...          ...
# 295       132.564713         True
# 296       139.940259        False
# 297       139.738926        False
# 298       140.797714        False
# 299       140.798629        False
#
# [300 rows x 7 columns]
#          base_price  hotel_latitude  hotel_longitude
# count    300.000000      300.000000       300.000000
# mean   20197.666667       36.672407       138.437448
# std    15270.012185        2.475990         3.450787
# min     3500.000000       33.491110       130.529900
# 25%     9300.000000       35.285222       136.985115
# 50%    15600.000000       35.716535       139.800617
# 75%    25125.000000       38.328767       140.793411
# max    74800.000000       43.165512       141.515930
#
#
#
#
# 表reserve:
#      reserve_id hotel_id customer_id     reserve_datetime checkin_date  \
# 0            r1     h_75         c_1  2016-03-06 13:09:42   2016-03-26
# 1            r2    h_219         c_1  2016-07-16 23:39:55   2016-07-20
# 2            r3    h_179         c_1  2016-09-24 10:03:17   2016-10-19
# 3            r4    h_214         c_1  2017-03-08 03:20:10   2017-03-29
# 4            r5     h_16         c_1  2017-09-05 19:50:37   2017-09-22
# ...         ...      ...         ...                  ...          ...
# 4025      r4026    h_129       c_999  2017-06-27 23:00:02   2017-07-10
# 4026      r4027     h_97       c_999  2017-09-29 05:24:57   2017-10-09
# 4027      r4028     h_27       c_999  2018-03-14 05:01:45   2018-04-02
# 4028      r4029     h_48      c_1000  2016-04-16 15:20:17   2016-05-10
# 4029      r4030    h_117      c_1000  2016-06-06 08:16:51   2016-07-06
#
#      checkin_time checkout_date  people_num  total_price
# 0        10:00:00    2016-03-29           4        97200
# 1        11:30:00    2016-07-21           2        20600
# 2        09:00:00    2016-10-22           2        33600
# 3        11:00:00    2017-03-30           4       194400
# 4        10:30:00    2017-09-23           3        68100
# ...           ...           ...         ...          ...
# 4025     09:30:00    2017-07-11           2        16000
# 4026     10:30:00    2017-10-10           2        41800
# 4027     11:30:00    2018-04-04           2        74800
# 4028     09:30:00    2016-05-13           4       540000
# 4029     09:00:00    2016-07-09           1        44100
#
# [4030 rows x 9 columns]
#         people_num    total_price
# count  4030.000000    4030.000000
# mean      2.542184  103065.955335
# std       1.120925  110288.484355
# min       1.000000    3500.000000
# 25%       2.000000   32400.000000
# 50%       3.000000   64800.000000
# 75%       4.000000  129600.000000
# max       4.000000  897600.000000

# %% [markdown]
# ## 异常值的识别和剔除
#     - 使用Z-score方法剔除异常值
# ## 规整化
#     - 属性字段数值化,将man处理为1,woman处理为0,并且把bool值处理为0/1值
#     - 归一化,把数据都归一化到[0,1]区间中,min值对应0,max值对应1
# ## 缺失值的填充
#     - 使用聚合值填充,这里使用中位数
#
# **注意:一定要在剔除异常值并且规整化之后后再填充缺失值**

# %%
# 对表customer使用Z-Score方法
zscore = (customer - customer.mean()) / customer.std()
zscore_r = zscore[abs(zscore) < 3]

# 对表customer进行归一化处理
new_customer = zscore_r / (zscore_r.max() - zscore_r.min())
print('归一化后的new_customer:')
new_customer['customer_id'] = customer['customer_id']
new_customer['sex'] = customer['sex']
print(new_customer)
# Out:
# 归一化后的new_customer:
#           age customer_id  home_latitude  home_longitude    sex
# 0   -0.151103         c_1      -0.123406       -0.053645    man
# 1   -0.195221         c_2      -0.099641        0.210229    man
# 2   -0.033456         c_3      -0.120513       -0.053752  woman
# 3   -0.121691         c_4       0.687127        0.376824    man
# 4   -0.298162         c_5      -0.122338       -0.052603    man
# ..        ...         ...            ...             ...    ...
# 995 -0.106985       c_996      -0.187344       -0.157309    man
# 996 -0.239338       c_997      -0.097570        0.210521    man
# 997 -0.283456       c_998       0.689923        0.379721  woman
# 998 -0.048162       c_999       0.190963        0.306161  woman
# 999 -0.180515      c_1000      -0.086647        0.210298    man
#
# [1000 rows x 5 columns]

# %%
# 表holiday_mst无需进行归一化处理
new_holiday_mst = holiday_mst

print(new_holiday_mst)
# Out:
#       target_day  holidayday_flg  nextday_is_holiday_flg
# 0     2016-01-01            True                    True
# 1     2016-01-02            True                    True
# 2     2016-01-03            True                   False
# 3     2016-01-04           False                   False
# 4     2016-01-05           False                   False
# ...          ...             ...                     ...
# 1181  2019-03-27           False                   False
# 1182  2019-03-28           False                   False
# 1183  2019-03-29           False                    True
# 1184  2019-03-30            True                    True
# 1185  2019-03-31            True                   False
#
# [1186 rows x 3 columns]

# %%
# 对表hotel进行Z-Score方法
zscore = (hotel - hotel.mean()) / hotel.std()
zscore_r = zscore[abs(zscore) < 3]

# 对表hotel进行归一化处理
new_hotel = zscore_r / (zscore_r.max() - zscore_r.min())
print('归一化后的new_hotel:')
new_hotel['hotel_id'] = hotel['hotel_id']
new_hotel['big_area_name'] = hotel['big_area_name']
new_hotel['small_area_name'] = hotel['small_area_name']
print(new_hotel)
# Out:
# 归一化后的new_hotel:
#      base_price big_area_name hotel_id  hotel_latitude  hotel_longitude  \
# 0      0.095817             D      h_1        0.660729         0.279805
# 1      0.100687             A      h_2       -0.098930         0.136719
# 2      0.342570             E      h_3       -0.143764        -0.131884
# 3     -0.243469             C      h_4        0.181808         0.214651
# 4     -0.108728             G      h_5       -0.317861        -0.719421
# ..          ...           ...      ...             ...              ...
# 295   -0.048663             F    h_296       -0.210244        -0.534564
# 296    0.159129             A    h_297       -0.088573         0.136793
# 297   -0.168793             A    h_298       -0.098730         0.118467
# 298    0.064973             C    h_299        0.171930         0.214842
# 299   -0.063274             C    h_300        0.161291         0.214926
#
#      is_business small_area_name
# 0       0.543333             D-2
# 1       0.543333             A-1
# 2      -0.456667             E-4
# 3      -0.456667             C-3
# 4       0.543333             G-3
# ..           ...             ...
# 295     0.543333             F-4
# 296    -0.456667             A-3
# 297    -0.456667             A-1
# 298    -0.456667             C-2
# 299    -0.456667             C-1
#
# [300 rows x 7 columns]

# %%
# 对表reserve进行Z-Score方法
zscore = (reserve - reserve.mean()) / reserve.std()
zscore_r = zscore[abs(zscore) < 3]

# 对表reserve进行归一化处理
new_reserve = zscore_r / (zscore_r.max() - zscore_r.min())
print('归一化后的new_reserve:')
new_reserve['checkin_date'] = reserve['checkin_date']
new_reserve['checkin_time'] = reserve['checkin_time']
new_reserve['checkout_date'] = reserve['checkout_date']
new_reserve['customer_id'] = reserve['customer_id']
new_reserve['hotel_id'] = reserve['hotel_id']
new_reserve['reserve_datetime'] = reserve['reserve_datetime']
new_reserve['reserve_id'] = reserve['reserve_id']
print(new_reserve)
# Out:
# 归一化后的new_reserve:
#      checkin_date checkin_time checkout_date customer_id hotel_id  people_num  \
# 0      2016-03-26     10:00:00    2016-03-29         c_1     h_75    0.485939
# 1      2016-07-20     11:30:00    2016-07-21         c_1    h_219   -0.180728
# 2      2016-10-19     09:00:00    2016-10-22         c_1    h_179   -0.180728
# 3      2017-03-29     11:00:00    2017-03-30         c_1    h_214    0.485939
# 4      2017-09-22     10:30:00    2017-09-23         c_1     h_16    0.152605
# ...           ...          ...           ...         ...      ...         ...
# 4025   2017-07-10     09:30:00    2017-07-11       c_999    h_129   -0.180728
# 4026   2017-10-09     10:30:00    2017-10-10       c_999     h_97   -0.180728
# 4027   2018-04-02     11:30:00    2018-04-04       c_999     h_27   -0.180728
# 4028   2016-05-10     09:30:00    2016-05-13      c_1000     h_48    0.485939
# 4029   2016-07-06     09:00:00    2016-07-09      c_1000    h_117   -0.514061
#
#          reserve_datetime reserve_id  total_price
# 0     2016-03-06 13:09:42         r1    -0.014064
# 1     2016-07-16 23:39:55         r2    -0.197713
# 2     2016-09-24 10:03:17         r3    -0.166545
# 3     2017-03-08 03:20:10         r4     0.218974
# 4     2017-09-05 19:50:37         r5    -0.083831
# ...                   ...        ...          ...
# 4025  2017-06-27 23:00:02      r4026    -0.208741
# 4026  2017-09-29 05:24:57      r4027    -0.146886
# 4027  2018-03-14 05:01:45      r4028    -0.067768
# 4028  2016-04-16 15:20:17      r4029          NaN
# 4029  2016-06-06 08:16:51      r4030    -0.141371
#
# [4030 rows x 9 columns]

# %%
# 表customer需要数据的规整化
customer = new_customer.replace('man',1)
customer = customer.replace('woman',0)

# 表holiday_mst需要数据的规整化
holiday_mst = new_holiday_mst.replace(True,1)
holiday_mst = holiday_mst.replace(False,0)

# 表hotel需要数据的规整化
hotel = new_hotel.replace(True,1)
hotel = hotel.replace(False,0)

# 表reserve不需要数据的规整化

print('表customer:')
print(customer)
print(customer.describe())
print('\n\n\n')

print('表holiday_mst:')
print(holiday_mst)
print(holiday_mst.describe())
print('\n\n\n')

print('表hotel:')
print(hotel)
print(hotel.describe())
print('\n\n\n')

print('表reserve:')
print(reserve)
print(reserve.describe())
print('\n\n\n')
# Out:
# 表customer:
#           age customer_id  home_latitude  home_longitude  sex
# 0   -0.151103         c_1      -0.123406       -0.053645    1
# 1   -0.195221         c_2      -0.099641        0.210229    1
# 2   -0.033456         c_3      -0.120513       -0.053752    0
# 3   -0.121691         c_4       0.687127        0.376824    1
# 4   -0.298162         c_5      -0.122338       -0.052603    1
# ..        ...         ...            ...             ...  ...
# 995 -0.106985       c_996      -0.187344       -0.157309    1
# 996 -0.239338       c_997      -0.097570        0.210521    1
# 997 -0.283456       c_998       0.689923        0.379721    0
# 998 -0.048162       c_999       0.190963        0.306161    0
# 999 -0.180515      c_1000      -0.086647        0.210298    1
#
# [1000 rows x 5 columns]
#                 age  home_latitude  home_longitude          sex
# count  1.000000e+03   1.000000e+03    1.000000e+03  1000.000000
# mean   2.983724e-17   2.554346e-16    1.607048e-16     0.518000
# std    2.171394e-01   3.086855e-01    3.269185e-01     0.499926
# min   -4.452206e-01  -3.099043e-01   -6.201050e-01     0.000000
# 25%   -1.805147e-01  -1.895050e-01   -1.572967e-01     0.000000
# 50%   -3.345588e-02  -1.027899e-01    2.084160e-01     1.000000
# 75%    1.724265e-01   1.908882e-01    3.049024e-01     1.000000
# max    5.547794e-01   6.900957e-01    3.798950e-01     1.000000
#
#
#
#
# 表holiday_mst:
#       target_day  holidayday_flg  nextday_is_holiday_flg
# 0     2016-01-01             1.0                     1.0
# 1     2016-01-02             1.0                     1.0
# 2     2016-01-03             1.0                     0.0
# 3     2016-01-04             0.0                     0.0
# 4     2016-01-05             0.0                     0.0
# ...          ...             ...                     ...
# 1181  2019-03-27             0.0                     0.0
# 1182  2019-03-28             0.0                     0.0
# 1183  2019-03-29             0.0                     1.0
# 1184  2019-03-30             1.0                     1.0
# 1185  2019-03-31             1.0                     0.0
#
# [1186 rows x 3 columns]
#        holidayday_flg  nextday_is_holiday_flg
# count     1186.000000             1186.000000
# mean         0.330523                0.329680
# std          0.470600                0.470295
# min          0.000000                0.000000
# 25%          0.000000                0.000000
# 50%          0.000000                0.000000
# 75%          1.000000                1.000000
# max          1.000000                1.000000
#
#
#
#
# 表hotel:
#      base_price big_area_name hotel_id  hotel_latitude  hotel_longitude  \
# 0      0.095817             D      h_1        0.660729         0.279805
# 1      0.100687             A      h_2       -0.098930         0.136719
# 2      0.342570             E      h_3       -0.143764        -0.131884
# 3     -0.243469             C      h_4        0.181808         0.214651
# 4     -0.108728             G      h_5       -0.317861        -0.719421
# ..          ...           ...      ...             ...              ...
# 295   -0.048663             F    h_296       -0.210244        -0.534564
# 296    0.159129             A    h_297       -0.088573         0.136793
# 297   -0.168793             A    h_298       -0.098730         0.118467
# 298    0.064973             C    h_299        0.171930         0.214842
# 299   -0.063274             C    h_300        0.161291         0.214926
#
#      is_business small_area_name
# 0       0.543333             D-2
# 1       0.543333             A-1
# 2      -0.456667             E-4
# 3      -0.456667             C-3
# 4       0.543333             G-3
# ..           ...             ...
# 295     0.543333             F-4
# 296    -0.456667             A-3
# 297    -0.456667             A-1
# 298    -0.456667             C-2
# 299    -0.456667             C-1
#
# [300 rows x 7 columns]
#        base_price  hotel_latitude  hotel_longitude   is_business
# count  293.000000    3.000000e+02     3.000000e+02  3.000000e+02
# mean    -0.019116    3.631354e-16    -7.574497e-16 -3.811766e-17
# std      0.217175    2.559321e-01     3.141068e-01  4.989510e-01
# min     -0.271066   -3.288366e-01    -7.197822e-01 -4.566667e-01
# 25%     -0.178534   -1.433872e-01    -1.321982e-01 -4.566667e-01
# 50%     -0.079508   -9.880421e-02     1.240820e-01 -4.566667e-01
# 75%      0.064973    1.712105e-01     2.144507e-01  5.433333e-01
# max      0.728934    6.711634e-01     2.802178e-01  5.433333e-01
#
#
#
#
# 表reserve:
#      reserve_id hotel_id customer_id     reserve_datetime checkin_date  \
# 0            r1     h_75         c_1  2016-03-06 13:09:42   2016-03-26
# 1            r2    h_219         c_1  2016-07-16 23:39:55   2016-07-20
# 2            r3    h_179         c_1  2016-09-24 10:03:17   2016-10-19
# 3            r4    h_214         c_1  2017-03-08 03:20:10   2017-03-29
# 4            r5     h_16         c_1  2017-09-05 19:50:37   2017-09-22
# ...         ...      ...         ...                  ...          ...
# 4025      r4026    h_129       c_999  2017-06-27 23:00:02   2017-07-10
# 4026      r4027     h_97       c_999  2017-09-29 05:24:57   2017-10-09
# 4027      r4028     h_27       c_999  2018-03-14 05:01:45   2018-04-02
# 4028      r4029     h_48      c_1000  2016-04-16 15:20:17   2016-05-10
# 4029      r4030    h_117      c_1000  2016-06-06 08:16:51   2016-07-06
#
#      checkin_time checkout_date  people_num  total_price
# 0        10:00:00    2016-03-29           4        97200
# 1        11:30:00    2016-07-21           2        20600
# 2        09:00:00    2016-10-22           2        33600
# 3        11:00:00    2017-03-30           4       194400
# 4        10:30:00    2017-09-23           3        68100
# ...           ...           ...         ...          ...
# 4025     09:30:00    2017-07-11           2        16000
# 4026     10:30:00    2017-10-10           2        41800
# 4027     11:30:00    2018-04-04           2        74800
# 4028     09:30:00    2016-05-13           4       540000
# 4029     09:00:00    2016-07-09           1        44100
#
# [4030 rows x 9 columns]
#         people_num    total_price
# count  4030.000000    4030.000000
# mean      2.542184  103065.955335
# std       1.120925  110288.484355
# min       1.000000    3500.000000
# 25%       2.000000   32400.000000
# 50%       3.000000   64800.000000
# 75%       4.000000  129600.000000
# max       4.000000  897600.000000

# %%
# 求这一行的聚合值,这里以中位数为聚合值,并用这些值填充None
customer_median = customer.median()
print(customer_median,end='\n\n')
customer = customer.fillna(customer_median)
print(customer)

holiday_mst_median = holiday_mst.median()
print(holiday_mst,end='\n\n')
holiday_mst = holiday_mst.fillna(holiday_mst_median)
print(holiday_mst)

hotel_median = hotel.median()
print(hotel_median,end='\n\n')
hotel = hotel.fillna(hotel_median)
print(hotel)

reserve_median = reserve.median()
print(reserve_median,end='\n\n')
reserve = reserve.fillna(reserve_median)
print(reserve)
# Out:
# age              -0.033456
# home_latitude    -0.102790
# home_longitude    0.208416
# sex               1.000000
# dtype: float64
#
#           age customer_id  home_latitude  home_longitude  sex
# 0   -0.151103         c_1      -0.123406       -0.053645    1
# 1   -0.195221         c_2      -0.099641        0.210229    1
# 2   -0.033456         c_3      -0.120513       -0.053752    0
# 3   -0.121691         c_4       0.687127        0.376824    1
# 4   -0.298162         c_5      -0.122338       -0.052603    1
# ..        ...         ...            ...             ...  ...
# 995 -0.106985       c_996      -0.187344       -0.157309    1
# 996 -0.239338       c_997      -0.097570        0.210521    1
# 997 -0.283456       c_998       0.689923        0.379721    0
# 998 -0.048162       c_999       0.190963        0.306161    0
# 999 -0.180515      c_1000      -0.086647        0.210298    1
#
# [1000 rows x 5 columns]
#       target_day  holidayday_flg  nextday_is_holiday_flg
# 0     2016-01-01             1.0                     1.0
# 1     2016-01-02             1.0                     1.0
# 2     2016-01-03             1.0                     0.0
# 3     2016-01-04             0.0                     0.0
# 4     2016-01-05             0.0                     0.0
# ...          ...             ...                     ...
# 1181  2019-03-27             0.0                     0.0
# 1182  2019-03-28             0.0                     0.0
# 1183  2019-03-29             0.0                     1.0
# 1184  2019-03-30             1.0                     1.0
# 1185  2019-03-31             1.0                     0.0
#
# [1186 rows x 3 columns]
#
#       target_day  holidayday_flg  nextday_is_holiday_flg
# 0     2016-01-01             1.0                     1.0
# 1     2016-01-02             1.0                     1.0
# 2     2016-01-03             1.0                     0.0
# 3     2016-01-04             0.0                     0.0
# 4     2016-01-05             0.0                     0.0
# ...          ...             ...                     ...
# 1181  2019-03-27             0.0                     0.0
# 1182  2019-03-28             0.0                     0.0
# 1183  2019-03-29             0.0                     1.0
# 1184  2019-03-30             1.0                     1.0
# 1185  2019-03-31             1.0                     0.0
#
# [1186 rows x 3 columns]
# base_price        -0.079508
# hotel_latitude    -0.098804
# hotel_longitude    0.124082
# is_business       -0.456667
# dtype: float64
#
#      base_price big_area_name hotel_id  hotel_latitude  hotel_longitude  \
# 0      0.095817             D      h_1        0.660729         0.279805
# 1      0.100687             A      h_2       -0.098930         0.136719
# 2      0.342570             E      h_3       -0.143764        -0.131884
# 3     -0.243469             C      h_4        0.181808         0.214651
# 4     -0.108728             G      h_5       -0.317861        -0.719421
# ..          ...           ...      ...             ...              ...
# 295   -0.048663             F    h_296       -0.210244        -0.534564
# 296    0.159129             A    h_297       -0.088573         0.136793
# 297   -0.168793             A    h_298       -0.098730         0.118467
# 298    0.064973             C    h_299        0.171930         0.214842
# 299   -0.063274             C    h_300        0.161291         0.214926
#
#      is_business small_area_name
# 0       0.543333             D-2
# 1       0.543333             A-1
# 2      -0.456667             E-4
# 3      -0.456667             C-3
# 4       0.543333             G-3
# ..           ...             ...
# 295     0.543333             F-4
# 296    -0.456667             A-3
# 297    -0.456667             A-1
# 298    -0.456667             C-2
# 299    -0.456667             C-1
#
# [300 rows x 7 columns]
# people_num         3.0
# total_price    64800.0
# dtype: float64
#
#      reserve_id hotel_id customer_id     reserve_datetime checkin_date  \
# 0            r1     h_75         c_1  2016-03-06 13:09:42   2016-03-26
# 1            r2    h_219         c_1  2016-07-16 23:39:55   2016-07-20
# 2            r3    h_179         c_1  2016-09-24 10:03:17   2016-10-19
# 3            r4    h_214         c_1  2017-03-08 03:20:10   2017-03-29
# 4            r5     h_16         c_1  2017-09-05 19:50:37   2017-09-22
# ...         ...      ...         ...                  ...          ...
# 4025      r4026    h_129       c_999  2017-06-27 23:00:02   2017-07-10
# 4026      r4027     h_97       c_999  2017-09-29 05:24:57   2017-10-09
# 4027      r4028     h_27       c_999  2018-03-14 05:01:45   2018-04-02
# 4028      r4029     h_48      c_1000  2016-04-16 15:20:17   2016-05-10
# 4029      r4030    h_117      c_1000  2016-06-06 08:16:51   2016-07-06
#
#      checkin_time checkout_date  people_num  total_price
# 0        10:00:00    2016-03-29           4        97200
# 1        11:30:00    2016-07-21           2        20600
# 2        09:00:00    2016-10-22           2        33600
# 3        11:00:00    2017-03-30           4       194400
# 4        10:30:00    2017-09-23           3        68100
# ...           ...           ...         ...          ...
# 4025     09:30:00    2017-07-11           2        16000
# 4026     10:30:00    2017-10-10           2        41800
# 4027     11:30:00    2018-04-04           2        74800
# 4028     09:30:00    2016-05-13           4       540000
# 4029     09:00:00    2016-07-09           1        44100
#
# [4030 rows x 9 columns]

# %%
print(hotel.isnull().sum())
# Out:
# base_price         0
# big_area_name      0
# hotel_id           0
# hotel_latitude     0
# hotel_longitude    0
# is_business        0
# small_area_name    0
# dtype: int64

# %%
from sklearn.decomposition import PCA
from sklearn import preprocessing
from sklearn import datasets
import matplotlib.pyplot as plt

view_data = hotel.loc[:,['base_price','hotel_latitude','hotel_longitude']]
print(view_data)

# 使用PAC降维,保留80%的特征
pca = PCA(n_components=0.8,whiten=True)

# view_data_pca
view_data_pca = pca.fit_transform(view_data)

#可视化
plt.plot(view_data_pca,'k^')
plt.show()
# Out:
#      base_price  hotel_latitude  hotel_longitude
# 0      0.095817        0.660729         0.279805
# 1      0.100687       -0.098930         0.136719
# 2      0.342570       -0.143764        -0.131884
# 3     -0.243469        0.181808         0.214651
# 4     -0.108728       -0.317861        -0.719421
# ..          ...             ...              ...
# 295   -0.048663       -0.210244        -0.534564
# 296    0.159129       -0.088573         0.136793
# 297   -0.168793       -0.098730         0.118467
# 298    0.064973        0.171930         0.214842
# 299   -0.063274        0.161291         0.214926
#
# [300 rows x 3 columns]
